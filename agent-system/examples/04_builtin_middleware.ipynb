# %% [markdown]
# # **04 빌트인 미들웨어 활용하기**
#
# ### 학습 내용
# 1. 미들웨어 개념 이해
# 2. LangChain 빌트인 미들웨어 사용하기

# %% [markdown]
# ## 0. 환경 설정
#
# - OpenAI API Key 발급: https://platform.openai.com/api-keys

# %%
import os
from dotenv import load_dotenv

load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI API Key가 설정되었습니다.")
# Out:
# OPENAI API Key가 설정되었습니다.

# %% [markdown]
# ## 1. 미들웨어란?
#
# ![image.png](attachment:image.png)
#
# **미들웨어(Middleware)** 는 에이전트 실행의 각 단계에서 동작을 제어하고 커스터마이징할 수 있는 메커니즘입니다.
#
# ### 미들웨어의 용도
#
# - **추적 및 로깅**: 에이전트 동작 모니터링, 분석, 디버깅
# - **변환**: 프롬프트, 도구 선택, 출력 형식 변경
# - **제어 흐름**: 재시도, 폴백, 조기 종료 로직
# - **제한 및 보호**: 속도 제한, 가드레일, PII 탐지
#
# ### 에이전트 실행 흐름
#
# ```
# before_agent
#     ↓
#     before_model → MODEL CALL → after_model
#     ↓
#     wrap_tool_call → TOOL EXECUTION
#     ↓
# after_agent
# ```

# %% [markdown]
# ## 2. 빌트인 미들웨어 1: TodoListMiddleware - 할일 계획 수립
#
# https://github.com/langchain-ai/langchain/blob/master/libs/langchain_v1/langchain/agents/middleware/todo.py

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import TodoListMiddleware
from langchain.tools import tool


# 여러 가짜 도구들 정의 (코드 리팩토링 시나리오)
@tool
def list_files(directory: str = ".") -> str:
    """프로젝트의 파일 목록을 가져옵니다."""
    return "main.py, utils.py, models.py, tests.py"

@tool
def read_file(filename: str) -> str:
    """파일의 내용을 읽습니다."""
    return f"{filename}의 내용 (1000줄)"

@tool
def analyze_code(filename: str) -> str:
    """코드의 품질을 분석합니다."""
    return f"{filename}: 복잡도 높음, 중복 코드 발견, 리팩토링 필요"

@tool
def refactor_code(filename: str, method: str) -> str:
    """코드를 리팩토링합니다."""
    return f"{filename}을(를) {method} 방식으로 리팩토링 완료"

@tool
def run_tests(test_file: str) -> str:
    """테스트를 실행합니다."""
    return f"{test_file}: 모든 테스트 통과 ✓"

@tool
def create_backup(files: str) -> str:
    """파일 백업을 생성합니다."""
    return f"{files} 백업 완료"

@tool
def commit_changes(message: str) -> str:
    """변경사항을 커밋합니다."""
    return f"커밋 완료: {message}"

@tool
def generate_documentation(filename: str) -> str:
    """코드 문서를 생성합니다."""
    return f"{filename}의 문서 생성 완료"

# TodoListMiddleware를 사용하는 에이전트
agent = create_agent(
    model="gpt-5.4-mini",
    tools=[
        list_files,
        read_file,
        analyze_code,
        refactor_code,
        run_tests,
        create_backup,
        commit_changes,
        generate_documentation,
    ],
    middleware=[TodoListMiddleware()], # write_todos / @wrap_model_call / @after_model(write_todos 도구가 여러번 호출되었으면 tools 노드로 보내지지 않도록 막음)
)

# %%
# Stream 모드로 에이전트의 계획 수립 과정 확인
user_message = [{"role": "user", "content": "레거시 코드베이스를 완전히 리팩토링하려고 합니다. 체계적으로 진행해주세요."}]

for i, chunk in enumerate(agent.stream({"messages": user_message}, stream_mode="updates"), 1):
    for node, value in chunk.items():
        print(f"\n━━━ 단계 {i}: {node} ━━━")

        # value가 None이 아닌 경우만 처리
        if value is not None and "messages" in value:
            for msg in value["messages"]:
                if hasattr(msg, 'content') and msg.content:
                    # AI 메시지의 경우
                    print(f"💬 AI: {msg.content}" if len(msg.content) > 200 else f"💬 AI: {msg.content}")

                # 도구 호출이 있는 경우
                if hasattr(msg, 'tool_calls') and msg.tool_calls:
                    for tool_call in msg.tool_calls:
                        print(f"🔧 도구 호출: {tool_call.get('name', 'unknown')}")
                        if 'args' in tool_call:
                            print(f"   인자: {tool_call['args']}")

                # 도구 응답인 경우
                if hasattr(msg, 'name') and msg.name:
                    print(f"✅ 도구 결과 ({msg.name}): {msg.content}" if len(msg.content) > 100 else f"✅ 도구 결과 ({msg.name}): {msg.content}")
                    print()
# Out:
# ━━━ 단계 1: model ━━━
# 🔧 도구 호출: write_todos
#    인자: {'todos': [{'content': '프로젝트 구조와 핵심 파일 파악', 'status': 'in_progress'}, {'content': '코드 품질/문제 지점 분석', 'status': 'pending'}, {'content': '리팩토링 전략 수립 및 우선순위 선정', 'status': 'pending'}, {'content': '필요한 파일 백업 생성', 'status': 'pending'}, {'content': '안전한 리팩토링 적용', 'status': 'pending'}, {'content': '테스트/정적분석 실행 및 검증', 'status': 'pending'}, {'content': '변경사항 정리 및 최종 보고', 'status': 'pending'}]}
#
# ━━━ 단계 2: TodoListMiddleware.after_model ━━━
#
# ━━━ 단계 3: tools ━━━
# 💬 AI: Updated todo list to [{'content': '프로젝트 구조와 핵심 파일 파악', 'status': 'in_progress'}, {'content': '코드 품질/문제 지점 분석', 'status': 'pending'}, {'content': '리팩토링 전략 수립 및 우선순위 선정', 'status': 'pending'}, {'content': '필요한 파일 백업 생성', 'status': 'pending'}, {'content': '안전한 리팩토링 적용', 'status': 'pending'}, {'content': '테스트/정적분석 실행 및 검증', 'status': 'pending'}, {'content': '변경사항 정리 및 최종 보고', 'status': 'pending'}]
# ✅ 도구 결과 (write_todos): Updated todo list to [{'content': '프로젝트 구조와 핵심 파일 파악', 'status': 'in_progress'}, {'content': '코드 품질/문제 지점 분석', 'status': 'pending'}, {'content': '리팩토링 전략 수립 및 우선순위 선정', 'status': 'pending'}, {'content': '필요한 파일 백업 생성', 'status': 'pending'}, {'content': '안전한 리팩토링 적용', 'status': 'pending'}, {'content': '테스트/정적분석 실행 및 검증', 'status': 'pending'}, {'content': '변경사항 정리 및 최종 보고', 'status': 'pending'}]
#
#
# ━━━ 단계 4: model ━━━
# 🔧 도구 호출: list_files
#    인자: {'directory': '.'}
# 🔧 도구 호출: list_files
#    인자: {'directory': './src'}
#
# ━━━ 단계 5: TodoListMiddleware.after_model ━━━
#
# ━━━ 단계 6: tools ━━━
# 💬 AI: main.py, utils.py, models.py, tests.py
# ✅ 도구 결과 (list_files): main.py, utils.py, models.py, tests.py
#
#
# ━━━ 단계 7: tools ━━━
# 💬 AI: main.py, utils.py, models.py, tests.py
# ✅ 도구 결과 (list_files): main.py, utils.py, models.py, tests.py
#
#
# ━━━ 단계 8: model ━━━
# 🔧 도구 호출: read_file
#    인자: {'filename': 'main.py'}
# 🔧 도구 호출: read_file
#    인자: {'filename': 'utils.py'}
# 🔧 도구 호출: read_file
#    인자: {'filename': 'models.py'}
# 🔧 도구 호출: read_file
#    인자: {'filename': 'tests.py'}
#
# ━━━ 단계 9: TodoListMiddleware.after_model ━━━
#
# ━━━ 단계 10: tools ━━━
# 💬 AI: utils.py의 내용 (1000줄)
# ✅ 도구 결과 (read_file): utils.py의 내용 (1000줄)
#
#
# ━━━ 단계 11: tools ━━━
# 💬 AI: models.py의 내용 (1000줄)
# ✅ 도구 결과 (read_file): models.py의 내용 (1000줄)
#
#
# ━━━ 단계 12: tools ━━━
# 💬 AI: main.py의 내용 (1000줄)
# ✅ 도구 결과 (read_file): main.py의 내용 (1000줄)
#
#
# ━━━ 단계 13: tools ━━━
# 💬 AI: tests.py의 내용 (1000줄)
# ✅ 도구 결과 (read_file): tests.py의 내용 (1000줄)
#
#
# ━━━ 단계 14: model ━━━
# 🔧 도구 호출: analyze_code
#    인자: {'filename': 'main.py'}
#
# ━━━ 단계 15: TodoListMiddleware.after_model ━━━
#
# ━━━ 단계 16: tools ━━━
# 💬 AI: main.py: 복잡도 높음, 중복 코드 발견, 리팩토링 필요
# ✅ 도구 결과 (analyze_code): main.py: 복잡도 높음, 중복 코드 발견, 리팩토링 필요
#
#
# ━━━ 단계 17: model ━━━
# 🔧 도구 호출: analyze_code
#    인자: {'filename': 'utils.py'}
#
# ━━━ 단계 18: TodoListMiddleware.after_model ━━━
#
# ━━━ 단계 19: tools ━━━
# 💬 AI: utils.py: 복잡도 높음, 중복 코드 발견, 리팩토링 필요
# ✅ 도구 결과 (analyze_code): utils.py: 복잡도 높음, 중복 코드 발견, 리팩토링 필요
#
#
# ━━━ 단계 20: model ━━━
# 🔧 도구 호출: analyze_code
#    인자: {'filename': 'models.py'}
#
# ━━━ 단계 21: TodoListMiddleware.after_model ━━━
#
# ━━━ 단계 22: tools ━━━
# 💬 AI: models.py: 복잡도 높음, 중복 코드 발견, 리팩토링 필요
# ✅ 도구 결과 (analyze_code): models.py: 복잡도 높음, 중복 코드 발견, 리팩토링 필요
#
#
# ━━━ 단계 23: model ━━━
# 🔧 도구 호출: analyze_code
#    인자: {'filename': 'tests.py'}
#
# ━━━ 단계 24: TodoListMiddleware.after_model ━━━
#
# ━━━ 단계 25: tools ━━━
# 💬 AI: tests.py: 복잡도 높음, 중복 코드 발견, 리팩토링 필요
# ✅ 도구 결과 (analyze_code): tests.py: 복잡도 높음, 중복 코드 발견, 리팩토링 필요
#
#
# ━━━ 단계 26: model ━━━
# 🔧 도구 호출: write_todos
#    인자: {'todos': [{'content': '프로젝트 구조와 핵심 파일 파악', 'status': 'completed'}, {'content': '코드 품질/문제 지점 분석', 'status': 'completed'}, {'content': '리팩토링 전략 수립 및 우선순위 선정', 'status': 'in_progress'}, {'content': '필요한 파일 백업 생성', 'status': 'pending'}, {'content': '안전한 리팩토링 적용', 'status': 'pending'}, {'content': '테스트/정적분석 실행 및 검증', 'status': 'pending'}, {'content': '변경사항 정리 및 최종 보고', 'status': 'pending'}]}
#
# ━━━ 단계 27: TodoListMiddleware.after_model ━━━
#
# ━━━ 단계 28: tools ━━━
# 💬 AI: Updated todo list to [{'content': '프로젝트 구조와 핵심 파일 파악', 'status': 'completed'}, {'content': '코드 품질/문제 지점 분석', 'status': 'completed'}, {'content': '리팩토링 전략 수립 및 우선순위 선정', 'status': 'in_progress'}, {'content': '필요한 파일 백업 생성', 'status': 'pending'}, {'content': '안전한 리팩토링 적용', 'status': 'pending'}, {'content': '테스트/정적분석 실행 및 검증', 'status': 'pending'}, {'content': '변경사항 정리 및 최종 보고', 'status': 'pending'}]
# ✅ 도구 결과 (write_todos): Updated todo list to [{'content': '프로젝트 구조와 핵심 파일 파악', 'status': 'completed'}, {'content': '코드 품질/문제 지점 분석', 'status': 'completed'}, {'content': '리팩토링 전략 수립 및 우선순위 선정', 'status': 'in_progress'}, {'content': '필요한 파일 백업 생성', 'status': 'pending'}, {'content': '안전한 리팩토링 적용', 'status': 'pending'}, {'content': '테스트/정적분석 실행 및 검증', 'status': 'pending'}, {'content': '변경사항 정리 및 최종 보고', 'status': 'pending'}]
#
#
# ━━━ 단계 29: model ━━━
# 💬 AI: 현재는 프로젝트의 파일 목록과 1차 품질 분석까지 완료했습니다.
# 구조상 `main.py`, `utils.py`, `models.py`, `tests.py`가 핵심이며, 전반적으로 **복잡도 높음 + 중복 코드 존재**가 확인되었습니다.
#
# 다음 단계로 체계적으로 진행하려면 아래 순서가 적절합니다:
#
# 1. **리팩토링 전략 수립**
#    - 책임 분리
#    - 중복 제거 우선순위 결정
#    - 핵심 로직/부수효과 분리
#    - 테스트 가능한 단위로 쪼개기
#
# 2. **안전장치 확보**
#    - 백업 생성
#    - 현재 테스트 기준선 확보
#    - 리팩토링 전후 동작 보장
#
# 3. **점진적 리팩토링**
#    - `main.py`: 진입점/오케스트레이션만 남기기
#    - `utils.py`: 순수 함수화, 공통 로직 정리
#    - `models.py`: 데이터 모델 단순화
#    - `tests.py`: 중복 제거 및 케이스 정리
#
# 4. **검증**
#    - 테스트 실행
#    - 정적 분석 재실행
#    - 회귀 여부 확인
#
# 원하시면 제가 바로 이어서:
# - **백업 생성**
# - **리팩토링 계획 구체화**
# - **실제 코드 수정**
# 까지 순서대로 진행하겠습니다.
#
# 진행 방식은 두 가지 중 선택하실 수 있습니다:
# - **보수적 리팩토링**: 동작 유지 최우선, 작은 단위로 안전하게
# - **대규모 정리형 리팩토링**: 구조를 크게 다시 설계
#
# 원하시는 방식을 말씀해 주시면 그에 맞춰 바로 진행하겠습니다.
#
# ━━━ 단계 30: TodoListMiddleware.after_model ━━━

# %% [markdown]
# ## 3. 빌트인 미들웨어 2: SummarizationMiddleware - 대화 히스토리 요약
#
# 긴 대화 히스토리를 자동으로 요약하여 컨텍스트 길이를 관리합니다.
#
# - 토큰 또는 메시지 수 기반 요약 트리거
# - 최근 메시지 보존
# - 오래된 컨텍스트 압축
# - 비용 절감
#
# https://github.com/langchain-ai/langchain/blob/master/libs/langchain_v1/langchain/agents/middleware/summarization.py

# %%
from langchain.tools import tool

@tool
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's sunny in {city}!"

@tool
def calculator(expression: str) -> str:
    """Evaluate a mathematical expression."""
    try:
        result = eval(expression, {"__builtins__": {}}, {})
        return f"Result: {result}"
    except Exception as e:
        return f"Error: {str(e)}"

# %%
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver

# 대화 요약 미들웨어
summary_agent = create_agent(
    model="gpt-5.4-mini",
    tools=[get_weather, calculator],
    checkpointer=InMemorySaver(),  # 상태 저장 필요
    middleware=[
        SummarizationMiddleware( # before_model
            model="gpt-4o-mini",
            # 6개 메시지에 도달하면 요약 시작 (테스트용으로 낮게 설정)
            trigger=("messages", 6),
            # 최근 3개 메시지는 보존
            keep=("messages", 3),
        )
    ],
)

# %%
# 요약 동작 확인을 위한 긴 대화
config = {"configurable": {"thread_id": "thread_1"}}

# 여러 메시지 전송
messages = [
    "안녕하세요, 서울의 날씨가 어떤가요?",
    "오늘은 외출을 해야겠네요.",
    "123 * 123 을 계산해주세요.",
    "도쿄의 날씨에 대해 알려주세요.",
    "100 - 50 을 계산해주세요.",
    "15 * 3 은 얼마인가요?",
    "파리의 날씨는 어떤가요?",
    "200 - 75 를 계산해주세요.",
]

for i, msg in enumerate(messages, 1):
    print(f"\n{'='*60}")
    print(f"📨 메시지 {i}/{len(messages)}: {msg}")
    print(f"{'='*60}")

    response = summary_agent.invoke(
        {"messages": [{"role": "user", "content": msg}]},
        config=config
    )

    total_msgs = len(response['messages'])
    user_msgs = sum(1 for m in response['messages'] if hasattr(m, 'type') and m.type == 'human')
    ai_msgs = sum(1 for m in response['messages'] if hasattr(m, 'type') and m.type == 'ai')

    print(f"응답: {response['messages'][-1].content}")
    print(f"메시지 현황: 총 {total_msgs}개 (사용자: {user_msgs}, AI: {ai_msgs})")
    for msg in response['messages']:
        print(f"- {msg.content}")
# Out:
# ============================================================
# 📨 메시지 1/8: 안녕하세요, 서울의 날씨가 어떤가요?
# ============================================================
# 응답: 서울은 현재 맑습니다.
# 메시지 현황: 총 4개 (사용자: 1, AI: 2)
# - 안녕하세요, 서울의 날씨가 어떤가요?
# -
# - It's sunny in 서울!
# - 서울은 현재 맑습니다.
#
# ============================================================
# 📨 메시지 2/8: 오늘은 외출을 해야겠네요.
# ============================================================
# 응답: 좋네요! 맑은 날이면 외출하기 딱 좋죠.
# 가볍게 외출하실 거면 선크림이나 물만 챙기셔도 괜찮고, 오래 나가시면 얇은 겉옷도 있으면 좋습니다.
# 메시지 현황: 총 6개 (사용자: 2, AI: 3)
# - 안녕하세요, 서울의 날씨가 어떤가요?
# -
# - It's sunny in 서울!
# - 서울은 현재 맑습니다.
# - 오늘은 외출을 해야겠네요.
# - 좋네요! 맑은 날이면 외출하기 딱 좋죠.
# 가볍게 외출하실 거면 선크림이나 물만 챙기셔도 괜찮고, 오래 나가시면 얇은 겉옷도 있으면 좋습니다.
#
# ============================================================
# 📨 메시지 3/8: 123 * 123 을 계산해주세요.
# ============================================================
# 응답: 123 × 123 = 15129 입니다.
# 메시지 현황: 총 5개 (사용자: 2, AI: 2)
# - Here is a summary of the conversation to date:
#
# ## SESSION INTENT
# The user requests information about the current weather in Seoul.
#
# ## SUMMARY
# The user inquired about the weather in Seoul, and it was confirmed that it is currently sunny in the city. The conversation then shifted to advising the user on how to prepare for going out, suggesting sunscreen and light clothing.
#
# ## ARTIFACTS
# None
#
# ## NEXT STEPS
# None
# - 123 * 123 을 계산해주세요.
# -
# - Result: 15129
# - 123 × 123 = 15129 입니다.
#
# ============================================================
# 📨 메시지 4/8: 도쿄의 날씨에 대해 알려주세요.
# ============================================================
# 응답: 도쿄는 현재 맑습니다.
# 메시지 현황: 총 5개 (사용자: 2, AI: 2)
# - Here is a summary of the conversation to date:
#
# ## SESSION INTENT
# The user requests information about the current weather in Seoul and the result of a multiplication.
#
# ## SUMMARY
# The user inquired about the weather in Seoul, confirming it is currently sunny, and received advice for preparation including sunscreen and light clothing. The user asked for the result of the multiplication 123 * 123, which was calculated to be 15129.
#
# ## ARTIFACTS
# None
#
# ## NEXT STEPS
# None
# - 도쿄의 날씨에 대해 알려주세요.
# -
# - It's sunny in Tokyo!
# - 도쿄는 현재 맑습니다.
#
# ============================================================
# 📨 메시지 5/8: 100 - 50 을 계산해주세요.
# ============================================================
# 응답: 100 - 50 = 50 입니다.
# 메시지 현황: 총 5개 (사용자: 2, AI: 2)
# - Here is a summary of the conversation to date:
#
# ## SESSION INTENT
# The user requests information about the current weather in Seoul and Tokyo, as well as the result of a multiplication.
#
# ## SUMMARY
# The user inquired about the weather in Seoul, which is currently sunny, and received advice for preparation including sunscreen and light clothing. The user also requested the result of the multiplication 123 * 123, which was calculated to be 15129. The user subsequently inquired about the weather in Tokyo, which is also sunny.
#
# ## ARTIFACTS
# None
#
# ## NEXT STEPS
# None
# - 100 - 50 을 계산해주세요.
# -
# - Result: 50
# - 100 - 50 = 50 입니다.
#
# ============================================================
# 📨 메시지 6/8: 15 * 3 은 얼마인가요?
# ============================================================
# 응답: 15 × 3은 **45**입니다.
# 메시지 현황: 총 5개 (사용자: 2, AI: 2)
# - Here is a summary of the conversation to date:
#
# ## SESSION INTENT
# The user requests information about the current weather in Seoul and Tokyo, as well as performing calculations involving multiplication and subtraction.
#
# ## SUMMARY
# The user inquired about the weather in Seoul, which is currently sunny, and received advice to prepare with sunscreen and light clothing. They also requested the result of the multiplication 123 * 123, which was calculated to be 15129. The weather in Tokyo was also confirmed to be sunny. Finally, the user asked for the calculation of 100 - 50, which resulted in 50.
#
# ## ARTIFACTS
# None
#
# ## NEXT STEPS
# None
# - 15 * 3 은 얼마인가요?
# -
# - Result: 45
# - 15 × 3은 **45**입니다.
#
# ============================================================
# 📨 메시지 7/8: 파리의 날씨는 어떤가요?
# ============================================================
# 응답: 파리 날씨는 **맑습니다**.
# 간단히 나가시기 좋은 날씨예요. 필요하시면 기온이나 주간 예보도 확인해드릴게요.
# 메시지 현황: 총 5개 (사용자: 2, AI: 2)
# - Here is a summary of the conversation to date:
#
# ## SESSION INTENT
# The user requests information about the current weather in Seoul and Tokyo, as well as performing calculations involving multiplication and subtraction.
#
# ## SUMMARY
# The user inquired about the weather in Seoul, which is currently sunny, and received advice to prepare with sunscreen and light clothing. They also requested the result of the multiplication 123 * 123, which was calculated to be 15129. The weather in Tokyo was confirmed to be sunny. Additionally, the user asked for the calculation of 100 - 50, which resulted in 50. The user also requested the result of the calculation 15 * 3, which was calculated to be 45.
#
# ## ARTIFACTS
# None
#
# ## NEXT STEPS
# None
# - 파리의 날씨는 어떤가요?
# -
# - It's sunny in Paris!
# - 파리 날씨는 **맑습니다**.
# 간단히 나가시기 좋은 날씨예요. 필요하시면 기온이나 주간 예보도 확인해드릴게요.
#
# ============================================================
# 📨 메시지 8/8: 200 - 75 를 계산해주세요.
# ============================================================
# 응답: 200 - 75 = 125 입니다.
# 메시지 현황: 총 5개 (사용자: 2, AI: 2)
# - Here is a summary of the conversation to date:
#
# ## SESSION INTENT
# The user requests information about the current weather in Seoul, Tokyo, and Paris, as well as calculations involving multiplication and subtraction.
#
# ## SUMMARY
# The user inquired about the weather in Seoul, which is sunny, and received advice to prepare with sunscreen and light clothing. The weather in Tokyo was also confirmed to be sunny. The user requested multiplication results: 123 * 123 calculated to 15129 and 15 * 3 calculated to 45. Additionally, the user requested a subtraction calculation of 100 - 50, which resulted in 50. The weather in Paris was confirmed to be sunny, with an offer to provide temperature or weekly forecasts if needed.
#
# ## ARTIFACTS
# None
#
# ## NEXT STEPS
# None
# - 200 - 75 를 계산해주세요.
# -
# - Result: 125
# - 200 - 75 = 125 입니다.

# %% [markdown]
# ## 4. 빌트인 미들웨어 3: ToolRetryMiddleware - 도구 재시도
#
# https://github.com/langchain-ai/langchain/blob/master/libs/langchain_v1/langchain/agents/middleware/tool_retry.py

# %% [markdown]
# **ToolRetryMiddleware 파라미터 정리**
#
# 1. `max_retries`
# - 재시도 횟수 (초기 1회 + retries)
# - 총 시도 횟수 = `max_retries + 1`
#
# 2. `tools`
# - retry 적용할 tool 지정
# - `None`이면 모든 tool에 적용
#
# 3. `retry_on`
# - 어떤 예외에서 retry할지 정의
# - 예외 타입 tuple 또는 함수로 설정 가능
#
# 4. `on_failure`
# - retries 모두 실패 시 동작
# - `"continue"`: ToolMessage 반환 (기본)
# - `"error"`: 예외 발생 (중단)
# - `callable`: 커스텀 메시지 반환
#
# 5. `backoff_factor`
# - 재시도 간 대기 시간 증가 비율 (exponential backoff)
# - `delay = initial_delay * (backoff_factor ** attempt)`
#
# 6. `initial_delay`
# - 첫 retry 전 대기 시간 (초)
#
# 7. `max_delay`
# - 최대 대기 시간 제한 (초)
#
# 8. `jitter`
# - 대기 시간에 ±랜덤 추가 (기본 ±25%)
# - 동시 재요청 폭발(Thundering Herd) 방지

# %%
from langchain.agents.middleware import ToolRetryMiddleware
import random

@tool
def flaky_api(query: str) -> str:
    """재시도 로직을 시연하기 위해 무작위로 실패하는 API"""
    import time
    print(f"⏱️ [{time.strftime('%H:%M:%S')}] flaky_api 호출 시도...")

    if random.random() < 0.7:  # 70% 실패 확률
        print(f"❌ [{time.strftime('%H:%M:%S')}] 실패: Network error")
        raise Exception("Network error")

    print(f"✅ [{time.strftime('%H:%M:%S')}] 성공!")
    return f"성공: {query}"

# 도구 재시도 미들웨어
tool_retry_agent = create_agent(
    model="gpt-5.4-mini",
    tools=[flaky_api],
    middleware=[
        ToolRetryMiddleware(
            max_retries=3,
            backoff_factor=2.0,
            initial_delay=0.5,
        )
    ],
)

# %%
user_message = [{"role": "user", "content": "Call the flaky API with 'test query'"}]

for i, chunk in enumerate(tool_retry_agent.stream({"messages": user_message}, stream_mode="updates"), 1):
    for node, value in chunk.items():
        print(node)
        print(value)
# Out:
# model
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 145, 'total_tokens': 164, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EBAHlojLSZlNrjc3Mb1iveL6eND8u', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe98e-6cb4-7621-8dfa-bb09424e8777-0', tool_calls=[{'name': 'flaky_api', 'args': {'query': 'test query'}, 'id': 'call_8diCTuzqfZQnjiUJPWFDDL8d', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 145, 'output_tokens': 19, 'total_tokens': 164, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ⏱️ [11:44:13] flaky_api 호출 시도...
# ❌ [11:44:13] 실패: Network error
# ⏱️ [11:44:14] flaky_api 호출 시도...
# ✅ [11:44:14] 성공!
# tools
# {'messages': [ToolMessage(content='성공: test query', name='flaky_api', id='3d6ae499-3c5f-41ef-9f2f-f423a5011e5f', tool_call_id='call_8diCTuzqfZQnjiUJPWFDDL8d')]}
# model
# {'messages': [AIMessage(content='API 호출 결과: 성공: test query', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 181, 'total_tokens': 192, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EBAHmbQHRK1wQ2J5HCxWuJYwUJ9nK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe98e-7174-7ae1-bf6d-27e8e4fd0fea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 181, 'output_tokens': 11, 'total_tokens': 192, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# - 미들웨어 없이 그냥 시도했을 때

# %%
tool_retry_agent = create_agent(
    model="gpt-5.4-mini",
    tools=[flaky_api])

# %%
user_message = [{"role": "user", "content": "Call the flaky API with 'test query'"}]

for i, chunk in enumerate(tool_retry_agent.stream({"messages": user_message}, stream_mode="updates"), 1):
    for node, value in chunk.items():
        print(node)
        print(value)
# Out:
# model
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 145, 'total_tokens': 164, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EBAIWoQOIsMwbL2vNlJcpnleKwJ4z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fe98f-21fc-7861-aa20-a0bfd8ff0c4d-0', tool_calls=[{'name': 'flaky_api', 'args': {'query': 'test query'}, 'id': 'call_38PE4bDKC8Zl7wOaHaUN7Ed3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 145, 'output_tokens': 19, 'total_tokens': 164, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ⏱️ [11:45:00] flaky_api 호출 시도...
# ❌ [11:45:00] 실패: Network error
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 user_message = [{"role": "user", "content": "Call the flaky API with 'test query'"}]
#       2
# ----> 3 for i, chunk in enumerate(tool_retry_agent.stream({"messages": user_message}, stream_mode="updates"), 1):
#       4     for node, value in chunk.items():
#       5         print(node)
#       6         print(value)
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:822, in ToolNode._func(self, input, config, runtime)
#     820 input_types = [input_type] * len(tool_calls)
#     821 with get_executor_for_config(config) as executor:
# --> 822     outputs = list(
#     823         executor.map(self._run_one, tool_calls, input_types, tool_runtimes)
#     824     )
#     826 return self._combine_tool_outputs(outputs, input_type)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langchain_core\runnables\config.py:650, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     649 def _wrapped_fn(*args: Any) -> T:
# --> 650     return contexts.pop().run(fn, *args)
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:1046, in ToolNode._run_one(self, call, input_type, tool_runtime)
#    1042 config = tool_runtime.config
#    1044 if self._wrap_tool_call is None:
#    1045     # No wrapper - execute directly
# -> 1046     return self._execute_tool_sync(tool_request, input_type, config)
#    1048 # Define execute callable that can be called multiple times
#    1049 def execute(req: ToolCallRequest) -> ToolMessage | Command:
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:1006, in ToolNode._execute_tool_sync(self, request, input_type, config)
#    1003     raise
#    1005 # Error is handled - create error ToolMessage
# -> 1006 content = _handle_tool_error(e, flag=self._handle_tool_errors)
#    1007 return ToolMessage(
#    1008     content=content,
#    1009     name=call["name"],
#    1010     tool_call_id=call["id"],
#    1011     status="error",
#    1012 )
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:434, in _handle_tool_error(e, flag)
#     432     content = flag
#     433 elif callable(flag):
# --> 434     content = flag(e)  # type: ignore [assignment, call-arg]
#     435 else:
#     436     msg = (
#     437         f"Got unexpected type of `handle_tool_error`. Expected bool, str "
#     438         f"or callable. Received: {flag}"
#     439     )
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:391, in _default_handle_tool_errors(e)
#     389 if isinstance(e, ToolInvocationError):
#     390     return e.message
# --> 391 raise e
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:958, in ToolNode._execute_tool_sync(self, request, input_type, config)
#     956 try:
#     957     try:
# --> 958         response = tool.invoke(call_args, config)
#     959     except ValidationError as exc:
#     960         # Filter out errors for injected arguments
#     961         injected = self._injected_args.get(call["name"])
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langchain_core\tools\base.py:738, in BaseTool.invoke(self, input, config, **kwargs)
#     730 @override
#     731 def invoke(
#     732     self,
#    (...)    735     **kwargs: Any,
#     736 ) -> Any:
#     737     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 738     return self.run(tool_input, **kwargs)
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langchain_core\tools\base.py:1100, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1098 if error_to_raise:
#    1099     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1100     raise error_to_raise
#    1101 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1102 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langchain_core\tools\base.py:1066, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1064     if config_param := _get_runnable_config_param(self._run):
#    1065         tool_kwargs |= {config_param: config}
# -> 1066     response = context.run(self._run, *tool_args, **tool_kwargs)
#    1067 if self.response_format == "content_and_artifact":
#    1068     msg = (
#    1069         "Since response_format='content_and_artifact' "
#    1070         "a two-tuple of the message content and raw tool output is "
#    1071         f"expected. Instead, generated response is of type: "
#    1072         f"{type(response)}."
#    1073     )
#
# File c:\Users\uoahv\OneDrive\Desktop\WORKSPACE\smu\smu-ai-service-bootcamp\agent-system\.venv\Lib\site-packages\langchain_core\tools\structured.py:97, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      95     if config_param := _get_runnable_config_param(self.func):
#      96         kwargs[config_param] = config
# ---> 97     return self.func(*args, **kwargs)
#      98 msg = "StructuredTool does not support sync invocation."
#      99 raise NotImplementedError(msg)
#
# Cell In[7], line 12, in flaky_api(query)
#       8     print(f"⏱️ [{time.strftime('%H:%M:%S')}] flaky_api 호출 시도...")
#       9
#      10     if random.random() < 0.7:  # 70% 실패 확률
#      11         print(f"❌ [{time.strftime('%H:%M:%S')}] 실패: Network error")
# ---> 12         raise Exception("Network error")
#      13
#      14     print(f"✅ [{time.strftime('%H:%M:%S')}] 성공!")
#      15     return f"성공: {query}"
#
# Exception: Network error
# During task with name 'tools' and id 'ceefeb13-a407-7141-df5f-d3148969a639'

# %% [markdown]
# ## 5. 빌트인 미들웨어 4: PIIMiddleware - 개인정보 보호
#
# 개인식별정보(PII)를 자동으로 탐지하고 처리합니다.
#
# - 이메일, 전화번호, IP 주소, MAC 주소, URL, 신용카드 탐지
# - PII 차단, 제거, 마스킹, 해싱 전략
# - 입력, 출력, 도구 결과에 선택적 적용
#
# ### 빌트인 PII 타입
#
# - `email`: 이메일 주소
# - `credit_card`: 신용카드 번호 (Luhn 알고리즘 검증)
# - `ip`: IP 주소
# - `mac_address`: MAC 주소
# - `url`: URL (http/https 및 일반 URL)
#
# https://github.com/langchain-ai/langchain/blob/master/libs/langchain_v1/langchain/agents/middleware/pii.py

# %%
from langchain.agents.middleware import PIIMiddleware

# PII 보호 미들웨어 (각 타입마다 별도 인스턴스)
pii_agent = create_agent(
    model="gpt-5.4-mini",
    tools=[get_weather, calculator],
    middleware=[
        # 이메일 제거
        PIIMiddleware(
            "email",
            strategy="redact",
            apply_to_input=True,
        ),
        # 신용카드 부분 마스킹
        PIIMiddleware(
            "credit_card",
            strategy="hash",
            apply_to_input=True,
        ),
        # IP 주소 해싱
        PIIMiddleware(
            "ip",
            strategy="hash",
            apply_to_input=True,
        ),
    ],
)

# %%
user_message = [{"role": "user", "content": "내 이메일은 john.doe@example.com, 카드번호는 4242 4242 4242 4242, IP는 192.168.1.1. 읽을 수 있어?"}]

for i, chunk in enumerate(pii_agent.stream({"messages": user_message}, stream_mode="updates"), 1):
    for node, value in chunk.items():
        print("---", node, "---")
        print(value)
# Out:
# --- PIIMiddleware[email].before_model ---
# {'messages': [HumanMessage(content='내 이메일은 [REDACTED_EMAIL], 카드번호는 4242 4242 4242 4242, IP는 192.168.1.1. 읽을 수 있어?', additional_kwargs={}, response_metadata={}, id='ed246968-bb81-4bea-9714-b2355e43d46a')]}
# --- PIIMiddleware[credit_card].before_model ---
# {'messages': [HumanMessage(content='내 이메일은 [REDACTED_EMAIL], 카드번호는 <credit_card_hash:9219e0af>, IP는 192.168.1.1. 읽을 수 있어?', additional_kwargs={}, response_metadata={}, id='ed246968-bb81-4bea-9714-b2355e43d46a')]}
# --- PIIMiddleware[ip].before_model ---
# {'messages': [HumanMessage(content='내 이메일은 [REDACTED_EMAIL], 카드번호는 <credit_card_hash:9219e0af>, IP는 <ip_hash:c5eb5a4c>. 읽을 수 있어?', additional_kwargs={}, response_metadata={}, id='ed246968-bb81-4bea-9714-b2355e43d46a')]}
# --- model ---
# {'messages': [AIMessage(content='직접 읽을 수는 없어요. 지금 보신 값들은 모두 마스킹/해시 처리된 형태라 원래 이메일, 카드번호, IP를 복원할 수 없습니다.\n\n- 이메일: `[REDACTED_EMAIL]` → 실제 주소가 가려짐\n- 카드번호: `<credit_card_hash:...>` → 해시값이라 원문 카드번호 복원 불가\n- IP: `<ip_hash:...>` → 해시값이라 원문 IP 복원 불가\n\n원하시면 제가 대신:\n- 형식이 올바른지 검증\n- 이메일/카드/IP 마스킹 규칙 설명\n- 보안상 안전하게 공유하는 방법 안내\n\n해드릴 수 있어요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 157, 'prompt_tokens': 185, 'total_tokens': 342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EBAHpBgGMJxwhkALBB7xP4NEHo2kb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fe98e-7bf1-70e1-8b4a-b39b48715f6a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 185, 'output_tokens': 157, 'total_tokens': 342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# --- PIIMiddleware[ip].after_model ---
# None
# --- PIIMiddleware[credit_card].after_model ---
# None
# --- PIIMiddleware[email].after_model ---
# None

# %% [markdown]
# ### 📖 과제 1: 빌트인 미들웨어 사용하기
#
# 아래 링크를 참고해서 Langchain 빌트인 미들웨어를 사용해보세요:
#
# https://docs.langchain.com/oss/python/langchain/middleware/built-in

# %%
# CODE HERE

# %% [markdown]
# ---
# ### 참고 자료
#
# - [Middleware Overview](https://docs.langchain.com/oss/python/langchain/middleware/overview)
# - [Built-in Middleware](https://docs.langchain.com/oss/python/langchain/middleware/built-in)
# - [Middleware API Reference](https://reference.langchain.com/python/langchain/middleware/)
